# %%
import pandas as pd
import numpy as np

# %%
dfCa = pd.read_csv('/media/scottcha/Data2/OAPMLData/caCombinedForecasts.csv')

# %%
dfCa['UnifiedRegion'] = dfCa['Region']

# %%
dfCa.tail()
# Out:
#       Region PublishedDateTime  Day1Date  SpecialStatement  \
# 15292  yukon    20210421 23:00  20210422               NaN
# 15293  yukon    20210423 23:00  20210424               NaN
# 15294  yukon    20210424 23:00  20210425               NaN
# 15295  yukon    20210426 23:00  20210427               NaN
# 15296  yukon    20210428 23:00  20210429               NaN
#
#                                        BottomLineSummary  \
# 15292  <p>A spring diurnal pattern dominates. Practic...
# 15293  <p>A spring diurnal pattern dominates. Best pr...
# 15294  <p>The Spring cycle continues and there is pot...
# 15295  <p>The region will see a return to winter this...
# 15296  <p>New snow and wind are forecast to arrive in...
#
#                                              ForecastUrl  \
# 15292  https://avalanche.ca/api/bulletin-archive/2021...
# 15293  https://avalanche.ca/api/bulletin-archive/2021...
# 15294  https://avalanche.ca/api/bulletin-archive/2021...
# 15295  https://avalanche.ca/api/bulletin-archive/2021...
# 15296  https://avalanche.ca/api/bulletin-archive/2021...
#
#       Day1DangerAboveTreeline Day1DangerNearTreeline Day1DangerBelowTreeline  \
# 15292                     Low                    Low                 no-data
# 15293                     Low                    Low                 no-data
# 15294                Moderate               Moderate                 no-data
# 15295                Moderate                    Low                 no-data
# 15296                Moderate                    Low                 no-data
#
#        Day1DetailedForecast  ...  WindSlabs_OctagonNearTreelineWest  \
# 15292                   NaN  ...                                  0
# 15293                   NaN  ...                                  0
# 15294                   NaN  ...                                  0
# 15295                   NaN  ...                                  0
# 15296                   NaN  ...                                  0
#
#       WindSlabs_OctagonBelowTreelineEast  WindSlabs_OctagonBelowTreelineNorth  \
# 15292                                  0                                    0
# 15293                                  0                                    0
# 15294                                  0                                    0
# 15295                                  0                                    0
# 15296                                  0                                    0
#
#       WindSlabs_OctagonBelowTreelineNorthEast  \
# 15292                                       0
# 15293                                       0
# 15294                                       0
# 15295                                       0
# 15296                                       0
#
#       WindSlabs_OctagonBelowTreelineNorthWest  \
# 15292                                       0
# 15293                                       0
# 15294                                       0
# 15295                                       0
# 15296                                       0
#
#       WindSlabs_OctagonBelowTreelineSouth  \
# 15292                                   0
# 15293                                   0
# 15294                                   0
# 15295                                   0
# 15296                                   0
#
#        WindSlabs_OctagonBelowTreelineSouthEast  \
# 15292                                        0
# 15293                                        0
# 15294                                        0
# 15295                                        0
# 15296                                        0
#
#        WindSlabs_OctagonBelowTreelineSouthWest  \
# 15292                                        0
# 15293                                        0
# 15294                                        0
# 15295                                        0
# 15296                                        0
#
#       WindSlabs_OctagonBelowTreelineWest  UnifiedRegion
# 15292                                  0          yukon
# 15293                                  0          yukon
# 15294                                  0          yukon
# 15295                                  0          yukon
# 15296                                  0          yukon
#
# [5 rows x 267 columns]

# %%
df = pd.read_csv('/media/scottcha/Data2/OAPMLData/CleanedForecastsNWAC_CAIC_UAC.V1.2013-2021.csv', low_memory=False).drop('Unnamed: 0', axis=1)

# %%
df[['Region', 'PublishedDateTime', 'Day1Date']].tail(100)
# Out:
#          Region    PublishedDateTime  Day1Date
# 27400  Southern  2021-05-02 00:11:00  20210502
# 27401   Central  2021-05-02 00:01:00  20210502
# 27402   Central  2021-05-02 00:01:00  20210502
# 27403  Southern  2021-05-03 00:01:00  20210503
# 27404  Southern  2021-05-04 00:01:00  20210504
# ...         ...                  ...       ...
# 27495  Southern  2021-05-31 16:34:00  20210531
# 27496  Southern  2021-05-31 16:34:00  20210531
# 27497  Northern  2021-06-01 00:01:00  20210601
# 27498   Central  2021-06-01 00:01:00  20210601
# 27499  Southern  2021-06-01 00:10:00  20210601
#
# [100 rows x 3 columns]

# %%
df.columns = ['BottomLineSummary',
     'Cornices_Likelihood',
     'Cornices_MaximumSize',
     'Cornices_MinimumSize',
     'Cornices_OctagonAboveTreelineEast',
     'Cornices_OctagonAboveTreelineNorth',
     'Cornices_OctagonAboveTreelineNorthEast',
     'Cornices_OctagonAboveTreelineNorthWest',
     'Cornices_OctagonAboveTreelineSouth',
     'Cornices_OctagonAboveTreelineSouthEast',
     'Cornices_OctagonAboveTreelineSouthWest',
     'Cornices_OctagonAboveTreelineWest',
     'Cornices_OctagonBelowTreelineEast',
     'Cornices_OctagonBelowTreelineNorth',
     'Cornices_OctagonBelowTreelineNorthEast',
     'Cornices_OctagonBelowTreelineNorthWest',
     'Cornices_OctagonBelowTreelineSouth',
     'Cornices_OctagonBelowTreelineSouthEast',
     'Cornices_OctagonBelowTreelineSouthWest',
     'Cornices_OctagonBelowTreelineWest',
     'Cornices_OctagonNearTreelineEast',
     'Cornices_OctagonNearTreelineNorth',
     'Cornices_OctagonNearTreelineNorthEast',
     'Cornices_OctagonNearTreelineNorthWest',
     'Cornices_OctagonNearTreelineSouth',
     'Cornices_OctagonNearTreelineSouthEast',
     'Cornices_OctagonNearTreelineSouthWest',
     'Cornices_OctagonNearTreelineWest',
     'Day1DangerAboveTreeline',
     'Day1DangerBelowTreeline',
     'Day1DangerNearTreeline',
     'Day1Danger_OctagonAboveTreelineEast',
     'Day1Danger_OctagonAboveTreelineNorth',
     'Day1Danger_OctagonAboveTreelineNorthEast',
     'Day1Danger_OctagonAboveTreelineNorthWest',
     'Day1Danger_OctagonAboveTreelineSouth',
     'Day1Danger_OctagonAboveTreelineSouthEast',
     'Day1Danger_OctagonAboveTreelineSouthWest',
     'Day1Danger_OctagonAboveTreelineWest',
     'Day1Danger_OctagonBelowTreelineEast',
     'Day1Danger_OctagonBelowTreelineNorth',
     'Day1Danger_OctagonBelowTreelineNorthEast',
     'Day1Danger_OctagonBelowTreelineNorthWest',
     'Day1Danger_OctagonBelowTreelineSouth',
     'Day1Danger_OctagonBelowTreelineSouthEast',
     'Day1Danger_OctagonBelowTreelineSouthWest',
     'Day1Danger_OctagonBelowTreelineWest',
     'Day1Danger_OctagonNearTreelineEast',
     'Day1Danger_OctagonNearTreelineNorth',
     'Day1Danger_OctagonNearTreelineNorthEast',
     'Day1Danger_OctagonNearTreelineNorthWest',
     'Day1Danger_OctagonNearTreelineSouth',
     'Day1Danger_OctagonNearTreelineSouthEast',
     'Day1Danger_OctagonNearTreelineSouthWest',
     'Day1Danger_OctagonNearTreelineWest',
     'Day1Date',
     'Day1DetailedForecast',
     'Day1Warning',
     'Day1WarningEnd',
     'Day1WarningText',
     'Day2DangerAboveTreeline',
     'Day2DangerBelowTreeline',
     'Day2DangerNearTreeline',
     'Day2DetailedForecast',
     'Day2Warning',
     'Day2WarningEnd',
     'Day2WarningText',
     'DeepPersistentSlabs_Likelihood',
     'DeepPersistentSlabs_MaximumSize',
     'DeepPersistentSlabs_MinimumSize',
     'DeepPersistentSlabs_OctagonAboveTreelineEast',
     'DeepPersistentSlabs_OctagonAboveTreelineNorth',
     'DeepPersistentSlabs_OctagonAboveTreelineNorthEast',
     'DeepPersistentSlabs_OctagonAboveTreelineNorthWest',
     'DeepPersistentSlabs_OctagonAboveTreelineSouth',
     'DeepPersistentSlabs_OctagonAboveTreelineSouthEast',
     'DeepPersistentSlabs_OctagonAboveTreelineSouthWest',
     'DeepPersistentSlabs_OctagonAboveTreelineWest',
     'DeepPersistentSlabs_OctagonBelowTreelineEast',
     'DeepPersistentSlabs_OctagonBelowTreelineNorth',
     'DeepPersistentSlabs_OctagonBelowTreelineNorthEast',
     'DeepPersistentSlabs_OctagonBelowTreelineNorthWest',
     'DeepPersistentSlabs_OctagonBelowTreelineSouth',
     'DeepPersistentSlabs_OctagonBelowTreelineSouthEast',
     'DeepPersistentSlabs_OctagonBelowTreelineSouthWest',
     'DeepPersistentSlabs_OctagonBelowTreelineWest',
     'DeepPersistentSlabs_OctagonNearTreelineEast',
     'DeepPersistentSlabs_OctagonNearTreelineNorth',
     'DeepPersistentSlabs_OctagonNearTreelineNorthEast',
     'DeepPersistentSlabs_OctagonNearTreelineNorthWest',
     'DeepPersistentSlabs_OctagonNearTreelineSouth',
     'DeepPersistentSlabs_OctagonNearTreelineSouthEast',
     'DeepPersistentSlabs_OctagonNearTreelineSouthWest',
     'DeepPersistentSlabs_OctagonNearTreelineWest',
     'ForecastUrl',
     'Glide_Likelihood',
     'Glide_MaximumSize',
     'Glide_MinimumSize',
     'Glide_OctagonAboveTreelineEast',
     'Glide_OctagonAboveTreelineNorth',
     'Glide_OctagonAboveTreelineNorthEast',
     'Glide_OctagonAboveTreelineNorthWest',
     'Glide_OctagonAboveTreelineSouth',
     'Glide_OctagonAboveTreelineSouthEast',
     'Glide_OctagonAboveTreelineSouthWest',
     'Glide_OctagonAboveTreelineWest',
     'Glide_OctagonBelowTreelineEast',
     'Glide_OctagonBelowTreelineNorth',
     'Glide_OctagonBelowTreelineNorthEast',
     'Glide_OctagonBelowTreelineNorthWest',
     'Glide_OctagonBelowTreelineSouth',
     'Glide_OctagonBelowTreelineSouthEast',
     'Glide_OctagonBelowTreelineSouthWest',
     'Glide_OctagonBelowTreelineWest',
     'Glide_OctagonNearTreelineEast',
     'Glide_OctagonNearTreelineNorth',
     'Glide_OctagonNearTreelineNorthEast',
     'Glide_OctagonNearTreelineNorthWest',
     'Glide_OctagonNearTreelineSouth',
     'Glide_OctagonNearTreelineSouthEast',
     'Glide_OctagonNearTreelineSouthWest',
     'Glide_OctagonNearTreelineWest',
     'IsCoastalSnowpack',
     'IsContenentalSnowpack',
     'LooseDry_Likelihood',
     'LooseDry_MaximumSize',
     'LooseDry_MinimumSize',
     'LooseDry_OctagonAboveTreelineEast',
     'LooseDry_OctagonAboveTreelineNorth',
     'LooseDry_OctagonAboveTreelineNorthEast',
     'LooseDry_OctagonAboveTreelineNorthWest',
     'LooseDry_OctagonAboveTreelineSouth',
     'LooseDry_OctagonAboveTreelineSouthEast',
     'LooseDry_OctagonAboveTreelineSouthWest',
     'LooseDry_OctagonAboveTreelineWest',
     'LooseDry_OctagonBelowTreelineEast',
     'LooseDry_OctagonBelowTreelineNorth',
     'LooseDry_OctagonBelowTreelineNorthEast',
     'LooseDry_OctagonBelowTreelineNorthWest',
     'LooseDry_OctagonBelowTreelineSouth',
     'LooseDry_OctagonBelowTreelineSouthEast',
     'LooseDry_OctagonBelowTreelineSouthWest',
     'LooseDry_OctagonBelowTreelineWest',
     'LooseDry_OctagonNearTreelineEast',
     'LooseDry_OctagonNearTreelineNorth',
     'LooseDry_OctagonNearTreelineNorthEast',
     'LooseDry_OctagonNearTreelineNorthWest',
     'LooseDry_OctagonNearTreelineSouth',
     'LooseDry_OctagonNearTreelineSouthEast',
     'LooseDry_OctagonNearTreelineSouthWest',
     'LooseDry_OctagonNearTreelineWest',
     'LooseWet_Likelihood',
     'LooseWet_MaximumSize',
     'LooseWet_MinimumSize',
     'LooseWet_OctagonAboveTreelineEast',
     'LooseWet_OctagonAboveTreelineNorth',
     'LooseWet_OctagonAboveTreelineNorthEast',
     'LooseWet_OctagonAboveTreelineNorthWest',
     'LooseWet_OctagonAboveTreelineSouth',
     'LooseWet_OctagonAboveTreelineSouthEast',
     'LooseWet_OctagonAboveTreelineSouthWest',
     'LooseWet_OctagonAboveTreelineWest',
     'LooseWet_OctagonBelowTreelineEast',
     'LooseWet_OctagonBelowTreelineNorth',
     'LooseWet_OctagonBelowTreelineNorthEast',
     'LooseWet_OctagonBelowTreelineNorthWest',
     'LooseWet_OctagonBelowTreelineSouth',
     'LooseWet_OctagonBelowTreelineSouthEast',
     'LooseWet_OctagonBelowTreelineSouthWest',
     'LooseWet_OctagonBelowTreelineWest',
     'LooseWet_OctagonNearTreelineEast',
     'LooseWet_OctagonNearTreelineNorth',
     'LooseWet_OctagonNearTreelineNorthEast',
     'LooseWet_OctagonNearTreelineNorthWest',
     'LooseWet_OctagonNearTreelineSouth',
     'LooseWet_OctagonNearTreelineSouthEast',
     'LooseWet_OctagonNearTreelineSouthWest',
     'LooseWet_OctagonNearTreelineWest',
     'PersistentSlabs_Likelihood',
     'PersistentSlabs_MaximumSize',
     'PersistentSlabs_MinimumSize',
     'PersistentSlabs_OctagonAboveTreelineEast',
     'PersistentSlabs_OctagonAboveTreelineNorth',
     'PersistentSlabs_OctagonAboveTreelineNorthEast',
     'PersistentSlabs_OctagonAboveTreelineNorthWest',
     'PersistentSlabs_OctagonAboveTreelineSouth',
     'PersistentSlabs_OctagonAboveTreelineSouthEast',
     'PersistentSlabs_OctagonAboveTreelineSouthWest',
     'PersistentSlabs_OctagonAboveTreelineWest',
     'PersistentSlabs_OctagonBelowTreelineEast',
     'PersistentSlabs_OctagonBelowTreelineNorth',
     'PersistentSlabs_OctagonBelowTreelineNorthEast',
     'PersistentSlabs_OctagonBelowTreelineNorthWest',
     'PersistentSlabs_OctagonBelowTreelineSouth',
     'PersistentSlabs_OctagonBelowTreelineSouthEast',
     'PersistentSlabs_OctagonBelowTreelineSouthWest',
     'PersistentSlabs_OctagonBelowTreelineWest',
     'PersistentSlabs_OctagonNearTreelineEast',
     'PersistentSlabs_OctagonNearTreelineNorth',
     'PersistentSlabs_OctagonNearTreelineNorthEast',
     'PersistentSlabs_OctagonNearTreelineNorthWest',
     'PersistentSlabs_OctagonNearTreelineSouth',
     'PersistentSlabs_OctagonNearTreelineSouthEast',
     'PersistentSlabs_OctagonNearTreelineSouthWest',
     'PersistentSlabs_OctagonNearTreelineWest',
     'PublishedDateTime',
     'Region',
     'SpecialStatement',
     'StormSlabs_Likelihood',
     'StormSlabs_MaximumSize',
     'StormSlabs_MinimumSize',
     'StormSlabs_OctagonAboveTreelineEast',
     'StormSlabs_OctagonAboveTreelineNorth',
     'StormSlabs_OctagonAboveTreelineNorthEast',
     'StormSlabs_OctagonAboveTreelineNorthWest',
     'StormSlabs_OctagonAboveTreelineSouth',
     'StormSlabs_OctagonAboveTreelineSouthEast',
     'StormSlabs_OctagonAboveTreelineSouthWest',
     'StormSlabs_OctagonAboveTreelineWest',
     'StormSlabs_OctagonBelowTreelineEast',
     'StormSlabs_OctagonBelowTreelineNorth',
     'StormSlabs_OctagonBelowTreelineNorthEast',
     'StormSlabs_OctagonBelowTreelineNorthWest',
     'StormSlabs_OctagonBelowTreelineSouth',
     'StormSlabs_OctagonBelowTreelineSouthEast',
     'StormSlabs_OctagonBelowTreelineSouthWest',
     'StormSlabs_OctagonBelowTreelineWest',
     'StormSlabs_OctagonNearTreelineEast',
     'StormSlabs_OctagonNearTreelineNorth',
     'StormSlabs_OctagonNearTreelineNorthEast',
     'StormSlabs_OctagonNearTreelineNorthWest',
     'StormSlabs_OctagonNearTreelineSouth',
     'StormSlabs_OctagonNearTreelineSouthEast',
     'StormSlabs_OctagonNearTreelineSouthWest',
     'StormSlabs_OctagonNearTreelineWest',
     'UnifiedRegion',
     'WetSlabs_Likelihood',
     'WetSlabs_MaximumSize',
     'WetSlabs_MinimumSize',
     'WetSlabs_OctagonAboveTreelineEast',
     'WetSlabs_OctagonAboveTreelineNorth',
     'WetSlabs_OctagonAboveTreelineNorthEast',
     'WetSlabs_OctagonAboveTreelineNorthWest',
     'WetSlabs_OctagonAboveTreelineSouth',
     'WetSlabs_OctagonAboveTreelineSouthEast',
     'WetSlabs_OctagonAboveTreelineSouthWest',
     'WetSlabs_OctagonAboveTreelineWest',
     'WetSlabs_OctagonBelowTreelineEast',
     'WetSlabs_OctagonBelowTreelineNorth',
     'WetSlabs_OctagonBelowTreelineNorthEast',
     'WetSlabs_OctagonBelowTreelineNorthWest',
     'WetSlabs_OctagonBelowTreelineSouth',
     'WetSlabs_OctagonBelowTreelineSouthEast',
     'WetSlabs_OctagonBelowTreelineSouthWest',
     'WetSlabs_OctagonBelowTreelineWest',
     'WetSlabs_OctagonNearTreelineEast',
     'WetSlabs_OctagonNearTreelineNorth',
     'WetSlabs_OctagonNearTreelineNorthEast',
     'WetSlabs_OctagonNearTreelineNorthWest',
     'WetSlabs_OctagonNearTreelineSouth',
     'WetSlabs_OctagonNearTreelineSouthEast',
     'WetSlabs_OctagonNearTreelineSouthWest',
     'WetSlabs_OctagonNearTreelineWest',
     'WindSlabs_Likelihood',
     'WindSlabs_MaximumSize',
     'WindSlabs_MinimumSize',
     'WindSlabs_OctagonAboveTreelineEast',
     'WindSlabs_OctagonAboveTreelineNorth',
     'WindSlabs_OctagonAboveTreelineNorthEast',
     'WindSlabs_OctagonAboveTreelineNorthWest',
     'WindSlabs_OctagonAboveTreelineSouth',
     'WindSlabs_OctagonAboveTreelineSouthEast',
     'WindSlabs_OctagonAboveTreelineSouthWest',
     'WindSlabs_OctagonAboveTreelineWest',
     'WindSlabs_OctagonBelowTreelineEast',
     'WindSlabs_OctagonBelowTreelineNorth',
     'WindSlabs_OctagonBelowTreelineNorthEast',
     'WindSlabs_OctagonBelowTreelineNorthWest',
     'WindSlabs_OctagonBelowTreelineSouth',
     'WindSlabs_OctagonBelowTreelineSouthEast',
     'WindSlabs_OctagonBelowTreelineSouthWest',
     'WindSlabs_OctagonBelowTreelineWest',
     'WindSlabs_OctagonNearTreelineEast',
     'WindSlabs_OctagonNearTreelineNorth',
     'WindSlabs_OctagonNearTreelineNorthEast',
     'WindSlabs_OctagonNearTreelineNorthWest',
     'WindSlabs_OctagonNearTreelineSouth',
     'WindSlabs_OctagonNearTreelineSouthEast',
     'WindSlabs_OctagonNearTreelineSouthWest',
     'WindSlabs_OctagonNearTreelineWest',
     'image_paths',
     'image_types',
     'image_urls',
     'rose_url']

# %%
list(df.columns)
# Out:
# ['BottomLineSummary',
#  'Cornices_Likelihood',
#  'Cornices_MaximumSize',
#  'Cornices_MinimumSize',
#  'Cornices_OctagonAboveTreelineEast',
#  'Cornices_OctagonAboveTreelineNorth',
#  'Cornices_OctagonAboveTreelineNorthEast',
#  'Cornices_OctagonAboveTreelineNorthWest',
#  'Cornices_OctagonAboveTreelineSouth',
#  'Cornices_OctagonAboveTreelineSouthEast',
#  'Cornices_OctagonAboveTreelineSouthWest',
#  'Cornices_OctagonAboveTreelineWest',
#  'Cornices_OctagonBelowTreelineEast',
#  'Cornices_OctagonBelowTreelineNorth',
#  'Cornices_OctagonBelowTreelineNorthEast',
#  'Cornices_OctagonBelowTreelineNorthWest',
#  'Cornices_OctagonBelowTreelineSouth',
#  'Cornices_OctagonBelowTreelineSouthEast',
#  'Cornices_OctagonBelowTreelineSouthWest',
#  'Cornices_OctagonBelowTreelineWest',
#  'Cornices_OctagonNearTreelineEast',
#  'Cornices_OctagonNearTreelineNorth',
#  'Cornices_OctagonNearTreelineNorthEast',
#  'Cornices_OctagonNearTreelineNorthWest',
#  'Cornices_OctagonNearTreelineSouth',
#  'Cornices_OctagonNearTreelineSouthEast',
#  'Cornices_OctagonNearTreelineSouthWest',
#  'Cornices_OctagonNearTreelineWest',
#  'Day1DangerAboveTreeline',
#  'Day1DangerBelowTreeline',
#  'Day1DangerNearTreeline',
#  'Day1Danger_OctagonAboveTreelineEast',
#  'Day1Danger_OctagonAboveTreelineNorth',
#  'Day1Danger_OctagonAboveTreelineNorthEast',
#  'Day1Danger_OctagonAboveTreelineNorthWest',
#  'Day1Danger_OctagonAboveTreelineSouth',
#  'Day1Danger_OctagonAboveTreelineSouthEast',
#  'Day1Danger_OctagonAboveTreelineSouthWest',
#  'Day1Danger_OctagonAboveTreelineWest',
#  'Day1Danger_OctagonBelowTreelineEast',
#  'Day1Danger_OctagonBelowTreelineNorth',
#  'Day1Danger_OctagonBelowTreelineNorthEast',
#  'Day1Danger_OctagonBelowTreelineNorthWest',
#  'Day1Danger_OctagonBelowTreelineSouth',
#  'Day1Danger_OctagonBelowTreelineSouthEast',
#  'Day1Danger_OctagonBelowTreelineSouthWest',
#  'Day1Danger_OctagonBelowTreelineWest',
#  'Day1Danger_OctagonNearTreelineEast',
#  'Day1Danger_OctagonNearTreelineNorth',
#  'Day1Danger_OctagonNearTreelineNorthEast',
#  'Day1Danger_OctagonNearTreelineNorthWest',
#  'Day1Danger_OctagonNearTreelineSouth',
#  'Day1Danger_OctagonNearTreelineSouthEast',
#  'Day1Danger_OctagonNearTreelineSouthWest',
#  'Day1Danger_OctagonNearTreelineWest',
#  'Day1Date',
#  'Day1DetailedForecast',
#  'Day1Warning',
#  'Day1WarningEnd',
#  'Day1WarningText',
#  'Day2DangerAboveTreeline',
#  'Day2DangerBelowTreeline',
#  'Day2DangerNearTreeline',
#  'Day2DetailedForecast',
#  'Day2Warning',
#  'Day2WarningEnd',
#  'Day2WarningText',
#  'DeepPersistentSlabs_Likelihood',
#  'DeepPersistentSlabs_MaximumSize',
#  'DeepPersistentSlabs_MinimumSize',
#  'DeepPersistentSlabs_OctagonAboveTreelineEast',
#  'DeepPersistentSlabs_OctagonAboveTreelineNorth',
#  'DeepPersistentSlabs_OctagonAboveTreelineNorthEast',
#  'DeepPersistentSlabs_OctagonAboveTreelineNorthWest',
#  'DeepPersistentSlabs_OctagonAboveTreelineSouth',
#  'DeepPersistentSlabs_OctagonAboveTreelineSouthEast',
#  'DeepPersistentSlabs_OctagonAboveTreelineSouthWest',
#  'DeepPersistentSlabs_OctagonAboveTreelineWest',
#  'DeepPersistentSlabs_OctagonBelowTreelineEast',
#  'DeepPersistentSlabs_OctagonBelowTreelineNorth',
#  'DeepPersistentSlabs_OctagonBelowTreelineNorthEast',
#  'DeepPersistentSlabs_OctagonBelowTreelineNorthWest',
#  'DeepPersistentSlabs_OctagonBelowTreelineSouth',
#  'DeepPersistentSlabs_OctagonBelowTreelineSouthEast',
#  'DeepPersistentSlabs_OctagonBelowTreelineSouthWest',
#  'DeepPersistentSlabs_OctagonBelowTreelineWest',
#  'DeepPersistentSlabs_OctagonNearTreelineEast',
#  'DeepPersistentSlabs_OctagonNearTreelineNorth',
#  'DeepPersistentSlabs_OctagonNearTreelineNorthEast',
#  'DeepPersistentSlabs_OctagonNearTreelineNorthWest',
#  'DeepPersistentSlabs_OctagonNearTreelineSouth',
#  'DeepPersistentSlabs_OctagonNearTreelineSouthEast',
#  'DeepPersistentSlabs_OctagonNearTreelineSouthWest',
#  'DeepPersistentSlabs_OctagonNearTreelineWest',
#  'ForecastUrl',
#  'Glide_Likelihood',
#  'Glide_MaximumSize',
#  'Glide_MinimumSize',
#  'Glide_OctagonAboveTreelineEast',
#  'Glide_OctagonAboveTreelineNorth',
#  'Glide_OctagonAboveTreelineNorthEast',
#  'Glide_OctagonAboveTreelineNorthWest',
#  'Glide_OctagonAboveTreelineSouth',
#  'Glide_OctagonAboveTreelineSouthEast',
#  'Glide_OctagonAboveTreelineSouthWest',
#  'Glide_OctagonAboveTreelineWest',
#  'Glide_OctagonBelowTreelineEast',
#  'Glide_OctagonBelowTreelineNorth',
#  'Glide_OctagonBelowTreelineNorthEast',
#  'Glide_OctagonBelowTreelineNorthWest',
#  'Glide_OctagonBelowTreelineSouth',
#  'Glide_OctagonBelowTreelineSouthEast',
#  'Glide_OctagonBelowTreelineSouthWest',
#  'Glide_OctagonBelowTreelineWest',
#  'Glide_OctagonNearTreelineEast',
#  'Glide_OctagonNearTreelineNorth',
#  'Glide_OctagonNearTreelineNorthEast',
#  'Glide_OctagonNearTreelineNorthWest',
#  'Glide_OctagonNearTreelineSouth',
#  'Glide_OctagonNearTreelineSouthEast',
#  'Glide_OctagonNearTreelineSouthWest',
#  'Glide_OctagonNearTreelineWest',
#  'IsCoastalSnowpack',
#  'IsContenentalSnowpack',
#  'LooseDry_Likelihood',
#  'LooseDry_MaximumSize',
#  'LooseDry_MinimumSize',
#  'LooseDry_OctagonAboveTreelineEast',
#  'LooseDry_OctagonAboveTreelineNorth',
#  'LooseDry_OctagonAboveTreelineNorthEast',
#  'LooseDry_OctagonAboveTreelineNorthWest',
#  'LooseDry_OctagonAboveTreelineSouth',
#  'LooseDry_OctagonAboveTreelineSouthEast',
#  'LooseDry_OctagonAboveTreelineSouthWest',
#  'LooseDry_OctagonAboveTreelineWest',
#  'LooseDry_OctagonBelowTreelineEast',
#  'LooseDry_OctagonBelowTreelineNorth',
#  'LooseDry_OctagonBelowTreelineNorthEast',
#  'LooseDry_OctagonBelowTreelineNorthWest',
#  'LooseDry_OctagonBelowTreelineSouth',
#  'LooseDry_OctagonBelowTreelineSouthEast',
#  'LooseDry_OctagonBelowTreelineSouthWest',
#  'LooseDry_OctagonBelowTreelineWest',
#  'LooseDry_OctagonNearTreelineEast',
#  'LooseDry_OctagonNearTreelineNorth',
#  'LooseDry_OctagonNearTreelineNorthEast',
#  'LooseDry_OctagonNearTreelineNorthWest',
#  'LooseDry_OctagonNearTreelineSouth',
#  'LooseDry_OctagonNearTreelineSouthEast',
#  'LooseDry_OctagonNearTreelineSouthWest',
#  'LooseDry_OctagonNearTreelineWest',
#  'LooseWet_Likelihood',
#  'LooseWet_MaximumSize',
#  'LooseWet_MinimumSize',
#  'LooseWet_OctagonAboveTreelineEast',
#  'LooseWet_OctagonAboveTreelineNorth',
#  'LooseWet_OctagonAboveTreelineNorthEast',
#  'LooseWet_OctagonAboveTreelineNorthWest',
#  'LooseWet_OctagonAboveTreelineSouth',
#  'LooseWet_OctagonAboveTreelineSouthEast',
#  'LooseWet_OctagonAboveTreelineSouthWest',
#  'LooseWet_OctagonAboveTreelineWest',
#  'LooseWet_OctagonBelowTreelineEast',
#  'LooseWet_OctagonBelowTreelineNorth',
#  'LooseWet_OctagonBelowTreelineNorthEast',
#  'LooseWet_OctagonBelowTreelineNorthWest',
#  'LooseWet_OctagonBelowTreelineSouth',
#  'LooseWet_OctagonBelowTreelineSouthEast',
#  'LooseWet_OctagonBelowTreelineSouthWest',
#  'LooseWet_OctagonBelowTreelineWest',
#  'LooseWet_OctagonNearTreelineEast',
#  'LooseWet_OctagonNearTreelineNorth',
#  'LooseWet_OctagonNearTreelineNorthEast',
#  'LooseWet_OctagonNearTreelineNorthWest',
#  'LooseWet_OctagonNearTreelineSouth',
#  'LooseWet_OctagonNearTreelineSouthEast',
#  'LooseWet_OctagonNearTreelineSouthWest',
#  'LooseWet_OctagonNearTreelineWest',
#  'PersistentSlabs_Likelihood',
#  'PersistentSlabs_MaximumSize',
#  'PersistentSlabs_MinimumSize',
#  'PersistentSlabs_OctagonAboveTreelineEast',
#  'PersistentSlabs_OctagonAboveTreelineNorth',
#  'PersistentSlabs_OctagonAboveTreelineNorthEast',
#  'PersistentSlabs_OctagonAboveTreelineNorthWest',
#  'PersistentSlabs_OctagonAboveTreelineSouth',
#  'PersistentSlabs_OctagonAboveTreelineSouthEast',
#  'PersistentSlabs_OctagonAboveTreelineSouthWest',
#  'PersistentSlabs_OctagonAboveTreelineWest',
#  'PersistentSlabs_OctagonBelowTreelineEast',
#  'PersistentSlabs_OctagonBelowTreelineNorth',
#  'PersistentSlabs_OctagonBelowTreelineNorthEast',
#  'PersistentSlabs_OctagonBelowTreelineNorthWest',
#  'PersistentSlabs_OctagonBelowTreelineSouth',
#  'PersistentSlabs_OctagonBelowTreelineSouthEast',
#  'PersistentSlabs_OctagonBelowTreelineSouthWest',
#  'PersistentSlabs_OctagonBelowTreelineWest',
#  'PersistentSlabs_OctagonNearTreelineEast',
#  'PersistentSlabs_OctagonNearTreelineNorth',
#  'PersistentSlabs_OctagonNearTreelineNorthEast',
#  'PersistentSlabs_OctagonNearTreelineNorthWest',
#  'PersistentSlabs_OctagonNearTreelineSouth',
#  'PersistentSlabs_OctagonNearTreelineSouthEast',
#  'PersistentSlabs_OctagonNearTreelineSouthWest',
#  'PersistentSlabs_OctagonNearTreelineWest',
#  'PublishedDateTime',
#  'Region',
#  'SpecialStatement',
#  'StormSlabs_Likelihood',
#  'StormSlabs_MaximumSize',
#  'StormSlabs_MinimumSize',
#  'StormSlabs_OctagonAboveTreelineEast',
#  'StormSlabs_OctagonAboveTreelineNorth',
#  'StormSlabs_OctagonAboveTreelineNorthEast',
#  'StormSlabs_OctagonAboveTreelineNorthWest',
#  'StormSlabs_OctagonAboveTreelineSouth',
#  'StormSlabs_OctagonAboveTreelineSouthEast',
#  'StormSlabs_OctagonAboveTreelineSouthWest',
#  'StormSlabs_OctagonAboveTreelineWest',
#  'StormSlabs_OctagonBelowTreelineEast',
#  'StormSlabs_OctagonBelowTreelineNorth',
#  'StormSlabs_OctagonBelowTreelineNorthEast',
#  'StormSlabs_OctagonBelowTreelineNorthWest',
#  'StormSlabs_OctagonBelowTreelineSouth',
#  'StormSlabs_OctagonBelowTreelineSouthEast',
#  'StormSlabs_OctagonBelowTreelineSouthWest',
#  'StormSlabs_OctagonBelowTreelineWest',
#  'StormSlabs_OctagonNearTreelineEast',
#  'StormSlabs_OctagonNearTreelineNorth',
#  'StormSlabs_OctagonNearTreelineNorthEast',
#  'StormSlabs_OctagonNearTreelineNorthWest',
#  'StormSlabs_OctagonNearTreelineSouth',
#  'StormSlabs_OctagonNearTreelineSouthEast',
#  'StormSlabs_OctagonNearTreelineSouthWest',
#  'StormSlabs_OctagonNearTreelineWest',
#  'UnifiedRegion',
#  'WetSlabs_Likelihood',
#  'WetSlabs_MaximumSize',
#  'WetSlabs_MinimumSize',
#  'WetSlabs_OctagonAboveTreelineEast',
#  'WetSlabs_OctagonAboveTreelineNorth',
#  'WetSlabs_OctagonAboveTreelineNorthEast',
#  'WetSlabs_OctagonAboveTreelineNorthWest',
#  'WetSlabs_OctagonAboveTreelineSouth',
#  'WetSlabs_OctagonAboveTreelineSouthEast',
#  'WetSlabs_OctagonAboveTreelineSouthWest',
#  'WetSlabs_OctagonAboveTreelineWest',
#  'WetSlabs_OctagonBelowTreelineEast',
#  'WetSlabs_OctagonBelowTreelineNorth',
#  'WetSlabs_OctagonBelowTreelineNorthEast',
#  'WetSlabs_OctagonBelowTreelineNorthWest',
#  'WetSlabs_OctagonBelowTreelineSouth',
#  'WetSlabs_OctagonBelowTreelineSouthEast',
#  'WetSlabs_OctagonBelowTreelineSouthWest',
#  'WetSlabs_OctagonBelowTreelineWest',
#  'WetSlabs_OctagonNearTreelineEast',
#  'WetSlabs_OctagonNearTreelineNorth',
#  'WetSlabs_OctagonNearTreelineNorthEast',
#  'WetSlabs_OctagonNearTreelineNorthWest',
#  'WetSlabs_OctagonNearTreelineSouth',
#  'WetSlabs_OctagonNearTreelineSouthEast',
#  'WetSlabs_OctagonNearTreelineSouthWest',
#  'WetSlabs_OctagonNearTreelineWest',
#  'WindSlabs_Likelihood',
#  'WindSlabs_MaximumSize',
#  'WindSlabs_MinimumSize',
#  'WindSlabs_OctagonAboveTreelineEast',
#  'WindSlabs_OctagonAboveTreelineNorth',
#  'WindSlabs_OctagonAboveTreelineNorthEast',
#  'WindSlabs_OctagonAboveTreelineNorthWest',
#  'WindSlabs_OctagonAboveTreelineSouth',
#  'WindSlabs_OctagonAboveTreelineSouthEast',
#  'WindSlabs_OctagonAboveTreelineSouthWest',
#  'WindSlabs_OctagonAboveTreelineWest',
#  'WindSlabs_OctagonBelowTreelineEast',
#  'WindSlabs_OctagonBelowTreelineNorth',
#  'WindSlabs_OctagonBelowTreelineNorthEast',
#  'WindSlabs_OctagonBelowTreelineNorthWest',
#  'WindSlabs_OctagonBelowTreelineSouth',
#  'WindSlabs_OctagonBelowTreelineSouthEast',
#  'WindSlabs_OctagonBelowTreelineSouthWest',
#  'WindSlabs_OctagonBelowTreelineWest',
#  'WindSlabs_OctagonNearTreelineEast',
#  'WindSlabs_OctagonNearTreelineNorth',
#  'WindSlabs_OctagonNearTreelineNorthEast',
#  'WindSlabs_OctagonNearTreelineNorthWest',
#  'WindSlabs_OctagonNearTreelineSouth',
#  'WindSlabs_OctagonNearTreelineSouthEast',
#  'WindSlabs_OctagonNearTreelineSouthWest',
#  'WindSlabs_OctagonNearTreelineWest',
#  'image_paths',
#  'image_types',
#  'image_urls',
#  'rose_url']

# %%
pd.isna(df.values)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ...,  True,  True,  True],
#        [ True, False, False, ...,  True,  True,  True],
#        [ True, False, False, ...,  True,  True,  True]])

# %%
df.shape
# Out:
# (27500, 294)

# %%
dfCa.shape
# Out:
# (15297, 267)

# %%
set(df.columns) - set(dfCa.columns)
# Out:
# {'Day1Danger_OctagonAboveTreelineEast',
#  'Day1Danger_OctagonAboveTreelineNorth',
#  'Day1Danger_OctagonAboveTreelineNorthEast',
#  'Day1Danger_OctagonAboveTreelineNorthWest',
#  'Day1Danger_OctagonAboveTreelineSouth',
#  'Day1Danger_OctagonAboveTreelineSouthEast',
#  'Day1Danger_OctagonAboveTreelineSouthWest',
#  'Day1Danger_OctagonAboveTreelineWest',
#  'Day1Danger_OctagonBelowTreelineEast',
#  'Day1Danger_OctagonBelowTreelineNorth',
#  'Day1Danger_OctagonBelowTreelineNorthEast',
#  'Day1Danger_OctagonBelowTreelineNorthWest',
#  'Day1Danger_OctagonBelowTreelineSouth',
#  'Day1Danger_OctagonBelowTreelineSouthEast',
#  'Day1Danger_OctagonBelowTreelineSouthWest',
#  'Day1Danger_OctagonBelowTreelineWest',
#  'Day1Danger_OctagonNearTreelineEast',
#  'Day1Danger_OctagonNearTreelineNorth',
#  'Day1Danger_OctagonNearTreelineNorthEast',
#  'Day1Danger_OctagonNearTreelineNorthWest',
#  'Day1Danger_OctagonNearTreelineSouth',
#  'Day1Danger_OctagonNearTreelineSouthEast',
#  'Day1Danger_OctagonNearTreelineSouthWest',
#  'Day1Danger_OctagonNearTreelineWest',
#  'IsCoastalSnowpack',
#  'IsContenentalSnowpack',
#  'image_paths',
#  'image_types',
#  'image_urls',
#  'rose_url'}

# %%
pd.concat([df, dfCa]).shape
# Out:
# (42797, 297)

# %%
combined_df = pd.concat([df, dfCa]).reset_index(drop=True)

# %%
combined_df[['UnifiedRegion', 'Day1Date', 'PublishedDateTime', 'Day1DangerAboveTreeline']].head()
# Out:
#                  UnifiedRegion  Day1Date PublishedDateTime  \
# 0                     Olympics  20131211    20131211 05:00
# 1  Cascade Pass - Stevens Pass  20131211    20131211 05:00
# 2    Cascade Pass - Snoq. Pass  20131211    20131211 05:00
# 3                      Mt Hood  20131211    20131211 05:00
# 4         Cascade West - North  20131211    20131211 05:00
#
#   Day1DangerAboveTreeline
# 0                Moderate
# 1                Moderate
# 2                Moderate
# 3                Moderate
# 4                Moderate

# %%
combined_df[combined_df['UnifiedRegion'] == 'Little Yoho']
# Out:
#                                        BottomLineSummary Cornices_Likelihood  \
# 30815  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 30816  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 30817  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 30818  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 30819  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# ...                                                  ...                 ...
# 31824  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 31825  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 31826  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
# 31827  !_!<style type= text/css > .p_CC664AAA { margi...          1-possible
# 31828  !_!<style type= text/css > .p_CC664AAA { margi...             no-data
#
#       Cornices_MaximumSize Cornices_MinimumSize  \
# 30815              no-data              no-data
# 30816              no-data              no-data
# 30817              no-data              no-data
# 30818              no-data              no-data
# 30819              no-data              no-data
# ...                    ...                  ...
# 31824              no-data              no-data
# 31825              no-data              no-data
# 31826              no-data              no-data
# 31827              1-large              0-small
# 31828              no-data              no-data
#
#       Cornices_OctagonAboveTreelineEast Cornices_OctagonAboveTreelineNorth  \
# 30815                                 0                                  0
# 30816                                 0                                  0
# 30817                                 0                                  0
# 30818                                 0                                  0
# 30819                                 0                                  0
# ...                                 ...                                ...
# 31824                                 0                                  0
# 31825                                 0                                  0
# 31826                                 0                                  0
# 31827                                 1                                  1
# 31828                                 0                                  0
#
#       Cornices_OctagonAboveTreelineNorthEast  \
# 30815                                      0
# 30816                                      0
# 30817                                      0
# 30818                                      0
# 30819                                      0
# ...                                      ...
# 31824                                      0
# 31825                                      0
# 31826                                      0
# 31827                                      1
# 31828                                      0
#
#       Cornices_OctagonAboveTreelineNorthWest  \
# 30815                                      0
# 30816                                      0
# 30817                                      0
# 30818                                      0
# 30819                                      0
# ...                                      ...
# 31824                                      0
# 31825                                      0
# 31826                                      0
# 31827                                      1
# 31828                                      0
#
#       Cornices_OctagonAboveTreelineSouth  \
# 30815                                  0
# 30816                                  0
# 30817                                  0
# 30818                                  0
# 30819                                  0
# ...                                  ...
# 31824                                  0
# 31825                                  0
# 31826                                  0
# 31827                                  1
# 31828                                  0
#
#       Cornices_OctagonAboveTreelineSouthEast  ...  \
# 30815                                      0  ...
# 30816                                      0  ...
# 30817                                      0  ...
# 30818                                      0  ...
# 30819                                      0  ...
# ...                                      ...  ...
# 31824                                      0  ...
# 31825                                      0  ...
# 31826                                      0  ...
# 31827                                      1  ...
# 31828                                      0  ...
#
#       WindSlabs_OctagonNearTreelineSouthEast  \
# 30815                                      0
# 30816                                      0
# 30817                                      0
# 30818                                      0
# 30819                                      0
# ...                                      ...
# 31824                                      0
# 31825                                      0
# 31826                                      0
# 31827                                      0
# 31828                                      0
#
#       WindSlabs_OctagonNearTreelineSouthWest  \
# 30815                                      0
# 30816                                      0
# 30817                                      0
# 30818                                      0
# 30819                                      0
# ...                                      ...
# 31824                                      0
# 31825                                      0
# 31826                                      0
# 31827                                      0
# 31828                                      0
#
#       WindSlabs_OctagonNearTreelineWest image_paths image_types image_urls  \
# 30815                                 0         NaN         NaN        NaN
# 30816                                 0         NaN         NaN        NaN
# 30817                                 0         NaN         NaN        NaN
# 30818                                 0         NaN         NaN        NaN
# 30819                                 0         NaN         NaN        NaN
# ...                                 ...         ...         ...        ...
# 31824                                 0         NaN         NaN        NaN
# 31825                                 0         NaN         NaN        NaN
# 31826                                 0         NaN         NaN        NaN
# 31827                                 0         NaN         NaN        NaN
# 31828                                 0         NaN         NaN        NaN
#
#       rose_url Day3DangerAboveTreeline Day3DangerNearTreeline  \
# 30815      NaN                 no-data                no-data
# 30816      NaN                 no-data                no-data
# 30817      NaN                    High                   High
# 30818      NaN                    High           Considerable
# 30819      NaN                    High                   High
# ...        ...                     ...                    ...
# 31824      NaN                 no-data                no-data
# 31825      NaN                 no-data                no-data
# 31826      NaN                 no-data                no-data
# 31827      NaN                 no-data                no-data
# 31828      NaN                 no-data                no-data
#
#       Day3DangerBelowTreeline
# 30815                 no-data
# 30816                 no-data
# 30817                 no-data
# 30818                Moderate
# 30819                Moderate
# ...                       ...
# 31824                 no-data
# 31825                 no-data
# 31826                 no-data
# 31827                 no-data
# 31828                 no-data
#
# [1014 rows x 297 columns]

# %%
combined_df.to_csv('/media/scottcha/Data2/OAPMLData/CleanedForecastsNWAC_CAIC_UAC_CAC.V1.2013-2021.csv')
