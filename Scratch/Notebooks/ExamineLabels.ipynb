# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('/media/scottcha/E1/Data/OAPMLData/CleanedForecastsNWAC_CAIC_UAC.V1.2013-2020.csv', parse_dates=True, low_memory=False)

# %%
df['parsed_date'] = pd.to_datetime(df['Day1Date'], format='%Y%m%d')

# %%
 def date_to_season(d):
        """
        mapping of date to season
        
        Keyword Arguments
        d: datetime64
        
        returns season indicator
        """
        if d >= np.datetime64('2013-11-01') and d <= np.datetime64('2014-04-30'):
            return (np.datetime64('2013-11-01'), '13-14')
        if d >= np.datetime64('2014-11-01') and d <= np.datetime64('2015-04-30'):
            return (np.datetime64('2014-11-01'), '14-15')
        elif d >= np.datetime64('2015-11-01') and d <= np.datetime64('2016-04-30'):
            return (np.datetime64('2015-11-01'), '15-16')
        elif d >= np.datetime64('2016-11-01') and d <= np.datetime64('2017-04-30'):
            return (np.datetime64('2016-11-01'), '16-17')
        elif d >= np.datetime64('2017-11-01') and d <= np.datetime64('2018-04-30'):
            return (np.datetime64('2017-11-01'), '17-18')        
        elif d >= np.datetime64('2018-11-01') and d <= np.datetime64('2019-04-30'):
            return (np.datetime64('2018-11-01'), '18-19')        
        elif d >= np.datetime64('2019-11-01') and d <= np.datetime64('2020-04-30'):            
            return (np.datetime64('2019-11-01'), '19-20')
        else:
            #print('Unknown season ' + str(d))
            return (None,'Unknown')

# %%
tmp = pd.DataFrame.from_records(df['parsed_date'].apply(date_to_season).reset_index(drop=True))
df.reset_index(drop=True, inplace=True)
df['season'] = tmp[1]

# %%
df[['UnifiedRegion', 'season', 'Day1Date']].groupby(['UnifiedRegion', 'season']).count().sort_values('Day1Date', ascending=False)
# Out:
#                                      Day1Date
# UnifiedRegion               season
# In The Desert               15-16         308
#                             16-17         308
#                             17-18         296
# Cascade East - South        13-14         278
# In The Desert               14-15         264
#                             13-14         254
# Steamboat & Flat Tops       15-16         159
# Cascade West - Central      17-18         155
# Aspen                       15-16         155
# Cascade West - South        17-18         155
# Cascade East - South        17-18         155
# Cascade East - North        17-18         155
# Mt Hood                     17-18         155
# Olympics                    17-18         155
# Low West                    17-18         155
# Cascade Pass - Snoq. Pass   17-18         155
# Cascade East - Central      17-18         155
# Cascade Pass - Stevens Pass 17-18         155
# Grand Mesa                  15-16         155
# Low East                    17-18         155
# Salt Lake                   16-17         154
# Front Range                 15-16         154
# Salt Lake                   15-16         154
# Cascade West - North        17-18         154
# In The Lake                 16-17         154
#                             15-16         154
# Grand Mesa                  17-18         153
# Sawatch Range               15-16         153
# Sangre de Cristo            15-16         152
# Cascade East - Central      16-17         151
# Cascade West - Central      16-17         151
# Aspen                       17-18         151
# Gunnison                    15-16         151
# Cascade West - North        16-17         151
# Vail & Summit County        15-16         151
# Cascade Pass - Stevens Pass 16-17         151
# Low East                    16-17         151
# Cascade West - South        16-17         151
# Cascade East - South        16-17         151
# Low West                    16-17         151
# Cascade Pass - Snoq. Pass   16-17         151
# Cascade East - North        16-17         151
# Mt Hood                     16-17         151
# Olympics                    16-17         151
# Sawatch Range               17-18         150
# Southern San Juan           15-16         150
# Gunnison                    17-18         149
# Steamboat & Flat Tops       17-18         149
# Front Range                 17-18         148
# In The Lake                 17-18         148
# Grand Mesa                  18-19          44
# Sawatch Range               18-19          44
# Southern San Juan           18-19          44
# Gunnison                    18-19          44
# Vail & Summit County        18-19          44
# Aspen                       18-19          42
# Cascade West - South        18-19          38
# Cascade West - North        18-19          34
# Cascade Pass - Snoq. Pass   18-19          34
# Skyline                     14-15          32
# Cascade West - North        19-20          29
# Olympics                    19-20          28
# Cascade West - Central      18-19          26
# Cascade East - Central      18-19          25
# Skyline                     13-14          25
# Cascade Pass - Stevens Pass 18-19          24
# Cascade East - North        18-19          23
# Olympics                    18-19          20
# Mt Hood                     18-19          20
# Cascade East - South        18-19          19
# Cascade West - Central      19-20          19
# Cascade Pass - Stevens Pass 19-20          19
# Cascade East - South        Unknown        18
# Cascade Pass - Snoq. Pass   19-20          14
# Mt Hood                     Unknown        13
# Cascade West - North        Unknown        13
# Cascade West - Central      Unknown        13
# Cascade East - Central      Unknown        13
# Low East                    Unknown        13
# Low West                    Unknown        13
# Cascade Pass - Stevens Pass Unknown        13
# Cascade West - South        Unknown        13
# Cascade Pass - Snoq. Pass   Unknown        13
# Olympics                    Unknown        13
# Cascade West - South        19-20          12
# Cascade East - Central      19-20          12
# Cascade East - North        19-20          11
# Cascade East - South        19-20          10
# Sangre de Cristo            Unknown         9
# Cascade East - North        Unknown         8
# Grand Mesa                  Unknown         8
# Front Range                 Unknown         7
# Mt Hood                     19-20           6
# Steamboat & Flat Tops       Unknown         6
# Logan                       Unknown         4
# In The Desert               Unknown         4
# Northern San Juan           Unknown         4
# Aspen                       Unknown         3
# Sawatch Range               Unknown         3
# Vail & Summit County        Unknown         3
# Southern San Juan           Unknown         3
# Gunnison                    Unknown         3
# Uintas                      Unknown         2
# Salt Lake                   Unknown         2
# In The Lake                 Unknown         2
# Skyline                     Unknown         1
# Provo                       Unknown         1
# Ogden                       Unknown         1

# %%
df18 = df[df['season']=='18-19']

# %%
dfFront = df18[df['UnifiedRegion']=='Front Range']
# Out:
# /home/scottcha/miniconda3/envs/pangeo_small3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
dfOlympics = df18[df['UnifiedRegion']=='Olympics']
# Out:
# /home/scottcha/miniconda3/envs/pangeo_small3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
dfFront['UnifiedRegion'].value_counts()
# Out:
# Front Range    44
# Name: UnifiedRegion, dtype: int64

# %%
dfFront.head(44)
# Out:
#       Cornices_Likelihood Cornices_MaximumSize Cornices_MinimumSize  \
# 21102             no-data              no-data              no-data
# 21113             no-data              no-data              no-data
# 21127             no-data              no-data              no-data
# 21136             no-data              no-data              no-data
# 21142             no-data              no-data              no-data
# 21151             no-data              no-data              no-data
# 21165             no-data              no-data              no-data
# 21171             no-data              no-data              no-data
# 21188             no-data              no-data              no-data
# 21193             no-data              no-data              no-data
# 21201             no-data              no-data              no-data
# 21213             no-data              no-data              no-data
# 21224             no-data              no-data              no-data
# 21235             no-data              no-data              no-data
# 21239             no-data              no-data              no-data
# 21252             no-data              no-data              no-data
# 21260             no-data              no-data              no-data
# 21273             no-data              no-data              no-data
# 21280             no-data              no-data              no-data
# 21289             no-data              no-data              no-data
# 21306             no-data              no-data              no-data
# 21312             no-data              no-data              no-data
# 21319             no-data              no-data              no-data
# 21328             no-data              no-data              no-data
# 21342             no-data              no-data              no-data
# 21350             no-data              no-data              no-data
# 21359             no-data              no-data              no-data
# 21370             no-data              no-data              no-data
# 21381             no-data              no-data              no-data
# 21397             no-data              no-data              no-data
# 21399             no-data              no-data              no-data
# 21409             no-data              no-data              no-data
# 21422             no-data              no-data              no-data
# 21431             no-data              no-data              no-data
# 21442             no-data              no-data              no-data
# 21448             no-data              no-data              no-data
# 21458             no-data              no-data              no-data
# 21470             no-data              no-data              no-data
# 21478             no-data              no-data              no-data
# 21491             no-data              no-data              no-data
# 21500             no-data              no-data              no-data
# 21507             no-data              no-data              no-data
# 21520             no-data              no-data              no-data
# 21532             no-data              no-data              no-data
#
#       Cornices_OctagonAboveTreelineEast Cornices_OctagonAboveTreelineNorth  \
# 21102                           no-data                            no-data
# 21113                           no-data                            no-data
# 21127                           no-data                            no-data
# 21136                           no-data                            no-data
# 21142                           no-data                            no-data
# 21151                           no-data                            no-data
# 21165                           no-data                            no-data
# 21171                           no-data                            no-data
# 21188                           no-data                            no-data
# 21193                           no-data                            no-data
# 21201                           no-data                            no-data
# 21213                           no-data                            no-data
# 21224                           no-data                            no-data
# 21235                           no-data                            no-data
# 21239                           no-data                            no-data
# 21252                           no-data                            no-data
# 21260                           no-data                            no-data
# 21273                           no-data                            no-data
# 21280                           no-data                            no-data
# 21289                           no-data                            no-data
# 21306                           no-data                            no-data
# 21312                           no-data                            no-data
# 21319                           no-data                            no-data
# 21328                           no-data                            no-data
# 21342                           no-data                            no-data
# 21350                           no-data                            no-data
# 21359                           no-data                            no-data
# 21370                           no-data                            no-data
# 21381                           no-data                            no-data
# 21397                           no-data                            no-data
# 21399                           no-data                            no-data
# 21409                           no-data                            no-data
# 21422                           no-data                            no-data
# 21431                           no-data                            no-data
# 21442                           no-data                            no-data
# 21448                           no-data                            no-data
# 21458                           no-data                            no-data
# 21470                           no-data                            no-data
# 21478                           no-data                            no-data
# 21491                           no-data                            no-data
# 21500                           no-data                            no-data
# 21507                           no-data                            no-data
# 21520                           no-data                            no-data
# 21532                           no-data                            no-data
#
#       Cornices_OctagonAboveTreelineNorthEast  \
# 21102                                no-data
# 21113                                no-data
# 21127                                no-data
# 21136                                no-data
# 21142                                no-data
# 21151                                no-data
# 21165                                no-data
# 21171                                no-data
# 21188                                no-data
# 21193                                no-data
# 21201                                no-data
# 21213                                no-data
# 21224                                no-data
# 21235                                no-data
# 21239                                no-data
# 21252                                no-data
# 21260                                no-data
# 21273                                no-data
# 21280                                no-data
# 21289                                no-data
# 21306                                no-data
# 21312                                no-data
# 21319                                no-data
# 21328                                no-data
# 21342                                no-data
# 21350                                no-data
# 21359                                no-data
# 21370                                no-data
# 21381                                no-data
# 21397                                no-data
# 21399                                no-data
# 21409                                no-data
# 21422                                no-data
# 21431                                no-data
# 21442                                no-data
# 21448                                no-data
# 21458                                no-data
# 21470                                no-data
# 21478                                no-data
# 21491                                no-data
# 21500                                no-data
# 21507                                no-data
# 21520                                no-data
# 21532                                no-data
#
#       Cornices_OctagonAboveTreelineNorthWest  \
# 21102                                no-data
# 21113                                no-data
# 21127                                no-data
# 21136                                no-data
# 21142                                no-data
# 21151                                no-data
# 21165                                no-data
# 21171                                no-data
# 21188                                no-data
# 21193                                no-data
# 21201                                no-data
# 21213                                no-data
# 21224                                no-data
# 21235                                no-data
# 21239                                no-data
# 21252                                no-data
# 21260                                no-data
# 21273                                no-data
# 21280                                no-data
# 21289                                no-data
# 21306                                no-data
# 21312                                no-data
# 21319                                no-data
# 21328                                no-data
# 21342                                no-data
# 21350                                no-data
# 21359                                no-data
# 21370                                no-data
# 21381                                no-data
# 21397                                no-data
# 21399                                no-data
# 21409                                no-data
# 21422                                no-data
# 21431                                no-data
# 21442                                no-data
# 21448                                no-data
# 21458                                no-data
# 21470                                no-data
# 21478                                no-data
# 21491                                no-data
# 21500                                no-data
# 21507                                no-data
# 21520                                no-data
# 21532                                no-data
#
#       Cornices_OctagonAboveTreelineSouth  \
# 21102                            no-data
# 21113                            no-data
# 21127                            no-data
# 21136                            no-data
# 21142                            no-data
# 21151                            no-data
# 21165                            no-data
# 21171                            no-data
# 21188                            no-data
# 21193                            no-data
# 21201                            no-data
# 21213                            no-data
# 21224                            no-data
# 21235                            no-data
# 21239                            no-data
# 21252                            no-data
# 21260                            no-data
# 21273                            no-data
# 21280                            no-data
# 21289                            no-data
# 21306                            no-data
# 21312                            no-data
# 21319                            no-data
# 21328                            no-data
# 21342                            no-data
# 21350                            no-data
# 21359                            no-data
# 21370                            no-data
# 21381                            no-data
# 21397                            no-data
# 21399                            no-data
# 21409                            no-data
# 21422                            no-data
# 21431                            no-data
# 21442                            no-data
# 21448                            no-data
# 21458                            no-data
# 21470                            no-data
# 21478                            no-data
# 21491                            no-data
# 21500                            no-data
# 21507                            no-data
# 21520                            no-data
# 21532                            no-data
#
#       Cornices_OctagonAboveTreelineSouthEast  \
# 21102                                no-data
# 21113                                no-data
# 21127                                no-data
# 21136                                no-data
# 21142                                no-data
# 21151                                no-data
# 21165                                no-data
# 21171                                no-data
# 21188                                no-data
# 21193                                no-data
# 21201                                no-data
# 21213                                no-data
# 21224                                no-data
# 21235                                no-data
# 21239                                no-data
# 21252                                no-data
# 21260                                no-data
# 21273                                no-data
# 21280                                no-data
# 21289                                no-data
# 21306                                no-data
# 21312                                no-data
# 21319                                no-data
# 21328                                no-data
# 21342                                no-data
# 21350                                no-data
# 21359                                no-data
# 21370                                no-data
# 21381                                no-data
# 21397                                no-data
# 21399                                no-data
# 21409                                no-data
# 21422                                no-data
# 21431                                no-data
# 21442                                no-data
# 21448                                no-data
# 21458                                no-data
# 21470                                no-data
# 21478                                no-data
# 21491                                no-data
# 21500                                no-data
# 21507                                no-data
# 21520                                no-data
# 21532                                no-data
#
#       Cornices_OctagonAboveTreelineSouthWest  ...  \
# 21102                                no-data  ...
# 21113                                no-data  ...
# 21127                                no-data  ...
# 21136                                no-data  ...
# 21142                                no-data  ...
# 21151                                no-data  ...
# 21165                                no-data  ...
# 21171                                no-data  ...
# 21188                                no-data  ...
# 21193                                no-data  ...
# 21201                                no-data  ...
# 21213                                no-data  ...
# 21224                                no-data  ...
# 21235                                no-data  ...
# 21239                                no-data  ...
# 21252                                no-data  ...
# 21260                                no-data  ...
# 21273                                no-data  ...
# 21280                                no-data  ...
# 21289                                no-data  ...
# 21306                                no-data  ...
# 21312                                no-data  ...
# 21319                                no-data  ...
# 21328                                no-data  ...
# 21342                                no-data  ...
# 21350                                no-data  ...
# 21359                                no-data  ...
# 21370                                no-data  ...
# 21381                                no-data  ...
# 21397                                no-data  ...
# 21399                                no-data  ...
# 21409                                no-data  ...
# 21422                                no-data  ...
# 21431                                no-data  ...
# 21442                                no-data  ...
# 21448                                no-data  ...
# 21458                                no-data  ...
# 21470                                no-data  ...
# 21478                                no-data  ...
# 21491                                no-data  ...
# 21500                                no-data  ...
# 21507                                no-data  ...
# 21520                                no-data  ...
# 21532                                no-data  ...
#
#       WindSlab_OctagonNearTreelineWest image_paths image_types image_urls  \
# 21102                          no-data     no-data     no-data    no-data
# 21113                          no-data     no-data     no-data    no-data
# 21127                          no-data     no-data     no-data    no-data
# 21136                          no-data     no-data     no-data    no-data
# 21142                          no-data     no-data     no-data    no-data
# 21151                          no-data     no-data     no-data    no-data
# 21165                          no-data     no-data     no-data    no-data
# 21171                          no-data     no-data     no-data    no-data
# 21188                                0     no-data     no-data    no-data
# 21193                          no-data     no-data     no-data    no-data
# 21201                          no-data     no-data     no-data    no-data
# 21213                          no-data     no-data     no-data    no-data
# 21224                          no-data     no-data     no-data    no-data
# 21235                          no-data     no-data     no-data    no-data
# 21239                          no-data     no-data     no-data    no-data
# 21252                          no-data     no-data     no-data    no-data
# 21260                          no-data     no-data     no-data    no-data
# 21273                          no-data     no-data     no-data    no-data
# 21280                          no-data     no-data     no-data    no-data
# 21289                          no-data     no-data     no-data    no-data
# 21306                          no-data     no-data     no-data    no-data
# 21312                          no-data     no-data     no-data    no-data
# 21319                          no-data     no-data     no-data    no-data
# 21328                          no-data     no-data     no-data    no-data
# 21342                                0     no-data     no-data    no-data
# 21350                                0     no-data     no-data    no-data
# 21359                                0     no-data     no-data    no-data
# 21370                                0     no-data     no-data    no-data
# 21381                                0     no-data     no-data    no-data
# 21397                                0     no-data     no-data    no-data
# 21399                          no-data     no-data     no-data    no-data
# 21409                          no-data     no-data     no-data    no-data
# 21422                          no-data     no-data     no-data    no-data
# 21431                          no-data     no-data     no-data    no-data
# 21442                                0     no-data     no-data    no-data
# 21448                                0     no-data     no-data    no-data
# 21458                                0     no-data     no-data    no-data
# 21470                                0     no-data     no-data    no-data
# 21478                                0     no-data     no-data    no-data
# 21491                                0     no-data     no-data    no-data
# 21500                                0     no-data     no-data    no-data
# 21507                                0     no-data     no-data    no-data
# 21520                                0     no-data     no-data    no-data
# 21532                          no-data     no-data     no-data    no-data
#
#       rose_url BottomLineSummary Day1WarningText Day2WarningText parsed_date  \
# 21102  no-data           no-data         no-data         no-data  2018-11-15
# 21113  no-data           no-data         no-data         no-data  2018-11-16
# 21127  no-data           no-data         no-data         no-data  2018-11-17
# 21136  no-data           no-data         no-data         no-data  2018-11-18
# 21142  no-data           no-data         no-data         no-data  2018-11-19
# 21151  no-data           no-data         no-data         no-data  2018-11-20
# 21165  no-data           no-data         no-data         no-data  2018-11-21
# 21171  no-data           no-data         no-data         no-data  2018-11-22
# 21188  no-data           no-data         no-data         no-data  2018-11-23
# 21193  no-data           no-data         no-data         no-data  2018-11-24
# 21201  no-data           no-data         no-data         no-data  2018-11-25
# 21213  no-data           no-data         no-data         no-data  2018-11-26
# 21224  no-data           no-data         no-data         no-data  2018-11-27
# 21235  no-data           no-data         no-data         no-data  2018-11-28
# 21239  no-data           no-data         no-data         no-data  2018-11-29
# 21252  no-data           no-data         no-data         no-data  2018-11-30
# 21260  no-data           no-data         no-data         no-data  2018-12-01
# 21273  no-data           no-data         no-data         no-data  2018-12-02
# 21280  no-data           no-data         no-data         no-data  2018-12-03
# 21289  no-data           no-data         no-data         no-data  2018-12-04
# 21306  no-data           no-data         no-data         no-data  2018-12-05
# 21312  no-data           no-data         no-data         no-data  2018-12-06
# 21319  no-data           no-data         no-data         no-data  2018-12-07
# 21328  no-data           no-data         no-data         no-data  2018-12-08
# 21342  no-data           no-data         no-data         no-data  2018-12-09
# 21350  no-data           no-data         no-data         no-data  2018-12-10
# 21359  no-data           no-data         no-data         no-data  2018-12-11
# 21370  no-data           no-data         no-data         no-data  2018-12-12
# 21381  no-data           no-data         no-data         no-data  2018-12-13
# 21397  no-data           no-data         no-data         no-data  2018-12-14
# 21399  no-data           no-data         no-data         no-data  2018-12-15
# 21409  no-data           no-data         no-data         no-data  2018-12-16
# 21422  no-data           no-data         no-data         no-data  2018-12-17
# 21431  no-data           no-data         no-data         no-data  2018-12-18
# 21442  no-data           no-data         no-data         no-data  2018-12-19
# 21448  no-data           no-data         no-data         no-data  2018-12-20
# 21458  no-data           no-data         no-data         no-data  2018-12-21
# 21470  no-data           no-data         no-data         no-data  2018-12-22
# 21478  no-data           no-data         no-data         no-data  2018-12-23
# 21491  no-data           no-data         no-data         no-data  2018-12-24
# 21500  no-data           no-data         no-data         no-data  2018-12-25
# 21507  no-data           no-data         no-data         no-data  2018-12-26
# 21520  no-data           no-data         no-data         no-data  2018-12-27
# 21532  no-data           no-data         no-data         no-data  2018-12-28
#
#       season
# 21102  18-19
# 21113  18-19
# 21127  18-19
# 21136  18-19
# 21142  18-19
# 21151  18-19
# 21165  18-19
# 21171  18-19
# 21188  18-19
# 21193  18-19
# 21201  18-19
# 21213  18-19
# 21224  18-19
# 21235  18-19
# 21239  18-19
# 21252  18-19
# 21260  18-19
# 21273  18-19
# 21280  18-19
# 21289  18-19
# 21306  18-19
# 21312  18-19
# 21319  18-19
# 21328  18-19
# 21342  18-19
# 21350  18-19
# 21359  18-19
# 21370  18-19
# 21381  18-19
# 21397  18-19
# 21399  18-19
# 21409  18-19
# 21422  18-19
# 21431  18-19
# 21442  18-19
# 21448  18-19
# 21458  18-19
# 21470  18-19
# 21478  18-19
# 21491  18-19
# 21500  18-19
# 21507  18-19
# 21520  18-19
# 21532  18-19
#
# [44 rows x 296 columns]

# %%
dfOlympics.head(30)
# Out:
#       Cornices_Likelihood Cornices_MaximumSize Cornices_MinimumSize  \
# 22266             no-data              no-data              no-data
# 22269             no-data              no-data              no-data
# 22275             no-data              no-data              no-data
# 22279             no-data              no-data              no-data
# 22283             no-data              no-data              no-data
# 22286             no-data              no-data              no-data
# 22297             no-data              no-data              no-data
# 22347             no-data              no-data              no-data
# 22396             no-data              no-data              no-data
# 22402             no-data              no-data              no-data
# 22433             no-data              no-data              no-data
# 22448             no-data              no-data              no-data
# 22463             no-data              no-data              no-data
# 22464             no-data              no-data              no-data
# 22475             no-data              no-data              no-data
# 22480             no-data              no-data              no-data
# 22482             no-data              no-data              no-data
# 22487             no-data              no-data              no-data
# 22497             no-data              no-data              no-data
# 22507             no-data              no-data              no-data
#
#       Cornices_OctagonAboveTreelineEast Cornices_OctagonAboveTreelineNorth
# 22286                                0     no-data     no-data    no-data
# 22297                                0     no-data     no-data    no-data
# 22347                                0     no-data     no-data    no-data
# 22396                                0     no-data     no-data    no-data
# 22402                                0     no-data     no-data    no-data
# 22433                                0     no-data     no-data    no-data
# 22448                                0     no-data     no-data    no-data
# 22463                                0     no-data     no-data    no-data
# 22464                                0     no-data     no-data    no-data
# 22475                                1     no-data     no-data    no-data
# 22480                                0     no-data     no-data    no-data
# 22482                                0     no-data     no-data    no-data
# 22487                                0     no-data     no-data    no-data
# 22497                                0     no-data     no-data    no-data
# 22507                                0     no-data     no-data    no-data
#
#       rose_url                                  BottomLineSummary  \
# 22266  no-data  <p>Unfortunately much of the recent precipitat...
# 22269  no-data  <p>Very stormy weather has created dangerous a...
# 22275  no-data  <p>Fresh and shallow wind slabs have likely fo...
# 22279  no-data  <p>Recently formed wind slabs may be found on ...
# 22283  no-data  <p>You are likely to find reactive snow on hig...
# 22286  no-data  <p>More than a foot of snow fell in Hurricane ...
# 22297  no-data  <p>Light snow and increasing winds will build ...
# 22347  no-data  <p>Skyrocketing snow levels to ridge crest by ...
# 22396  no-data  <p>You can still trigger a large and life-thre...
# 22402  no-data  <p>An estimated 3-6&rdquo; of new snow fell in...
# 22433  no-data  <p>Don&#39;t mistake low danger for no danger....
# 22448  no-data  <p>You may trigger shallow avalanches that bre...
# 22463  no-data  <p>Watch for spring sun effects on slopes with...
# 22464  no-data  <p>While we have no specific avalanche problem...
# 22475  no-data  <p>A strong spring storm has created dangerous...
# 22480  no-data  <p>A cooling trend and increased winds should ...
# 22482  no-data  <p>Help us improve the avalanche forecast! &nb...
# 22487  no-data                                            no-data
# 22497  no-data  <p>Daily avalanche forecasts have ended for th...
# 22507  no-data  <p>Daily avalanche forecasts have ended for th...
#
#                                          Day1WarningText Day2WarningText  \
# 22266  <p>The mountains of the PNW have received a si...         no-data
# 22269                                            no-data         no-data
# 22275                                            no-data         no-data
# 22279                                            no-data         no-data
# 22283                                            no-data         no-data
# 22286                                            no-data         no-data
# 22297                                            no-data         no-data
# 22347                                            no-data         no-data
# 22396  <p>An unstable snowpack  combined with increas...         no-data
# 22402                                            no-data         no-data
# 22433                                            no-data         no-data
# 22448                                            no-data         no-data
# 22463                                            no-data         no-data
# 22464                                            no-data         no-data
# 22475                                            no-data         no-data
# 22480                                            no-data         no-data
# 22482                                            no-data         no-data
# 22487                                            no-data         no-data
# 22497                                            no-data         no-data
# 22507                                            no-data         no-data
#
#       parsed_date season
# 22266  2018-12-15  18-19
# 22269  2018-12-18  18-19
# 22275  2018-12-21  18-19
# 22279  2018-12-22  18-19
# 22283  2018-12-23  18-19
# 22286  2018-12-24  18-19
# 22297  2018-12-28  18-19
# 22347  2019-01-22  18-19
# 22396  2019-02-17  18-19
# 22402  2019-02-21  18-19
# 22433  2019-03-09  18-19
# 22448  2019-03-16  18-19
# 22463  2019-03-29  18-19
# 22464  2019-03-30  18-19
# 22475  2019-04-07  18-19
# 22480  2019-04-10  18-19
# 22482  2019-04-11  18-19
# 22487  2019-04-15  18-19
# 22497  2019-04-16  18-19
# 22507  2019-04-18  18-19
#
# [20 rows x 296 columns]
